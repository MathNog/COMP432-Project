# %% [markdown]
# ## ARIMA Model
#
# ### Description:
#
# This notebook will implement code for time series analysis and forecasting with ARIMA models.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# ### Some useful functions

# %%
#Ploting a single time series

def plot_series(serie,title,xlabel,ylabel):
    plt.figure()
    plt.plot(serie)
    plt.title=title
    plt.xlabel=xlabel
    plt.ylabel=ylabel
    plt.show()

# %%
#Importing the dataset and making some changes

series = pd.read_csv('../data/SeriesReport-Not Seasonally Adjusted Sales - Monthly (Millions of Dollars).csv')
series.rename(columns = {'Period':'Month'}, inplace = True) #changing from period to month so that we can know the serios periodicy
series.set_index("Month",inplace=True)
series.index=pd.to_datetime(series.index)
series.head()
# Out:
#                Value
# Month
# 1992-01-01  146376.0
# 1992-01-02  147079.0
# 1992-01-03  159336.0
# 1992-01-04  163669.0
# 1992-01-05  170068.0

# %% [markdown]
# ### Checkpoint
#
# Before moving one, we shall look for missing values in the data, because, if they exist, they will result in errors in the future.

# %%
series.describe() #it does not seem to have any missing value
# Out:
#                Value
# count     341.000000
# mean   334869.967742
# std    103322.404489
# min    146376.000000
# 25%    250580.000000
# 50%    336134.000000
# 75%    414714.000000
# max    591380.000000

# %%
series.isnull() # we have missing values, let's find exactly were they are
# Out:
#             Value
# Month
# 1992-01-01  False
# 1992-01-02  False
# 1992-01-03  False
# 1992-01-04  False
# 1992-01-05  False
# ...           ...
# 2020-01-08   True
# 2020-01-09   True
# 2020-01-10   True
# 2020-01-11   True
# 2020-01-12   True
#
# [348 rows x 1 columns]

# %%
series.tail(n=10) # it seems that our missing values are ust the 7 last entries, so we decide to simply drop them
# Out:
#                Value
# Month
# 2020-01-03  481513.0
# 2020-01-04  410345.0
# 2020-01-05  507477.0
# 2020-01-06       NaN
# 2020-01-07       NaN
# 2020-01-08       NaN
# 2020-01-09       NaN
# 2020-01-10       NaN
# 2020-01-11       NaN
# 2020-01-12       NaN

# %%
series = series.dropna()
series.isnull().sum() # good, now we dont have any missing values
# Out:
# Value    0
# dtype: int64

# %%
#Visualizing the Series

plot_series(series,"USA Sales - Monthly",xlabel="Month",ylabel="Millions of Dollars")

# %% [markdown]
# ## Coments regarding the series behavior
#
# By seeing the series it seems both seasonal and non-stationary.
# In order to verify our assumption, we will pass the serie through a stationarity test and a seasonal decomposition

# %%
adf = adfuller(series.Value)
print(adf)
# Out:
# (-1.1590618603297136, 0.6909538471619209, 16, 324, {'1%': -3.450695263332383, '5%': -2.87050218926466, '10%': -2.5715449066453284}, 6846.217749155032)

# %%
series_diff1 = series - series.shift(1)
series_diff1 = series_diff1.dropna()
plot_series(series_diff1,"USA Sales - Monthly - 1 diff",xlabel="Month",ylabel="Millions of Dollars")

# %%
adf = adfuller(series_diff1.Value)
print(adf)
# Out:
# (-3.409280817196374, 0.010646528723802442, 17, 322, {'1%': -3.4508226600665037, '5%': -2.870558121868621, '10%': -2.571574731684734}, 6822.139808092065)

# %% [markdown]
# ### Conclusion regarding stationarity
#
# The second value from the variable adf is the p-value, which tells if the series is stationary or not.
# Since it is bigger than 0.05, the **Null Hypothesis** is not rejected, hence the series is **not stationary**.
#
# We have differenciated the series in order to get a stationary series, even though the ARIMA Model could have taken care of this, since the *I* in *ARIMA* means *Integrated*, so this model is able the differenciate a Time Series if needed. One differentiation was enought to have a p-values smaller than 0.05

# %%
seasonal_result = seasonal_decompose(series_diff1,period=12)
seasonal_result.plot()

# %% [markdown]
# ### Conclusion regarding Seasonality
#
# As observed in the plot, our time series have a seasonal behavior.
#
# We wont deal with seasonality in order to see if Neural Networks, the core of this project, is influenced by it or not. With that being said, we will keep this series at is is.

# %% [markdown]
# ## Correlation Analysis
#
# The next step in out Time Series Analysis should be to create the **Autocorrelation and Partial Autocorrelation Functions**, in order to determine the parameters of the **ARIMA Model**.
#
# ### ARIMA Model Brief Introduction
#
# The fundamentals of ARIMA Models are, actually, two other Time Series Models, the AR and MA.
#
# The **AR**, Autoregressive Model, takes the past values of the series to predict the future ones. It relies on the assumption that the present values is a linear combination of lagged values.
#
# The **MA**, Moving Average Model, relies on the assumption that the regression errors are a linear combination of the errors terms from past values.
#
# The **ARIMA** model combines those two models and, also, is capable of *differenciate* the series to get a stationary behavior, since this is an assumption of the model as well.
#
# In order to determine the parameters of the model, the past values that will be used to predict the present and future ones, we use the Autocorrelation and Partialcorrelation functions.
#
# As we can see, this model is quite restrictive, even though is a classic model. We aim to see if Forecasting with Neural Networks will be a more flexible and precise approach.

# %%
plot_acf(series_diff1)

# %%
plot_pacf(series_diff1)
# Out:
# C:\Users\matno\miniconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ### Parameters chosen
#
# Since the significant lags are, for both functions 1, we will chose the orders to be (1,0,1).
#
# Note that, in the autocorrelation function, we have a significant lag every 12 months, the series seasonal period.
#
# Note that the *d* parameter is zero because we have already differentiated the series

# %% [markdown]
# ## Training and Test Sets
#
# We must divide our time series into a training and test sample. Since our series has anual seasonality, let's leave the 2 last years as test samples and the rest of the series as training.

# %%
train_series = series_diff1.iloc[0:len(series_diff1)-24,:]
test_series = series_diff1.iloc[len(series_diff1)-24:,:]

# %%
model_arima = ARIMA(train_series,order=(1,1,1)).fit()
# Out:
# C:\Users\matno\miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\matno\miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\matno\miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
print(model_arima.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Value   No. Observations:                  316
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3709.710
# Date:                Mon, 01 Nov 2021   AIC                           7425.421
# Time:                        23:50:51   BIC                           7436.679
# Sample:                             0   HQIC                          7429.919
#                                 - 316
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4041      0.063     -6.411      0.000      -0.528      -0.281
# ma.L1         -0.9968      0.097    -10.313      0.000      -1.186      -0.807
# sigma2      1.333e+09    5.7e-11   2.34e+19      0.000    1.33e+09    1.33e+09
# ...

# %%
model_arima.resid.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
model_sarima=SARIMAX(train_series,order=(1,0,1),seasonal_order=(0, 0, 0, 12))
# Out:
# C:\Users\matno\miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\matno\miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
model_sarima.resid.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8096/324293397.py in <module>
# ----> 1 model_sarima.resid.plot()
#
# AttributeError: 'SARIMAX' object has no attribute 'resid'
